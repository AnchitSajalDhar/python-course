# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %%
pd1=pd.read_csv("HollywoodMovies.csv",low_memory=False)
pd1.head()
# Out:
#                                        Movie   LeadStudio  RottenTomatoes  \
# 0                               Spider-Man 3         Sony            61.0
# 1                            Shrek the Third    Paramount            42.0
# 2                               Transformers    Paramount            57.0
# 3   Pirates of the Caribbean: At World's End       Disney            45.0
# 4  Harry Potter and the Order of the Phoenix  Warner Bros            78.0
#
#    AudienceScore          Story      Genre  TheatersOpenWeek  OpeningWeekend  \
# 0           54.0  Metamorphosis     Action            4252.0           151.1
# 1           57.0          Quest  Animation            4122.0           121.6
# 2           89.0  Monster Force     Action            4011.0            70.5
# 3           74.0         Rescue     Action            4362.0           114.7
# 4           82.0          Quest  Adventure            4285.0            77.1
#
# ...

# %%
pd1.shape
# Out:
# (970, 16)

# %%
pd1
# Out:
#                                          Movie              LeadStudio  \
# 0                                 Spider-Man 3                    Sony
# 1                              Shrek the Third               Paramount
# 2                                 Transformers               Paramount
# 3     Pirates of the Caribbean: At World's End                  Disney
# 4    Harry Potter and the Order of the Phoenix             Warner Bros
# ..                                         ...                     ...
# 965                                The Canyons                     IFC
# 966                                   The Call                 TriStar
# 967                        The English Teacher  Cinedigm Entertainment
# 968                       John Dies at the End                Magnolia
# 969                                   Lovelace              Radius-TWC
#
#      RottenTomatoes  AudienceScore          Story      Genre  \
# ...

# %%
pd2=pd1[pd1["Story"]=="Quest"].max()
pd2
# Out:
# Movie               Year One
# RottenTomatoes            97
# AudienceScore             87
# Story                  Quest
# TheatersOpenWeek        4325
# OpeningWeekend           125
# BOAvgOpenWeekend       36338
# DomesticGross         352.39
# ForeignGross          804.64
# WorldGross           1123.79
# Budget                   250
# Profitability        1371.24
# OpenProfit            164.71
# Year                    2011
# dtype: object

# %%
dataset=pd.read_csv('HollywoodMovies.csv')
selected_data=dataset.loc[:,['Movie','Story','RottenTomatoes']]
df=pd.DataFrame(selected_data)
df_movie_filter = df[(df.Story == 'Quest') & (df.Story.notnull())]
output = df_movie_filter[df_movie_filter.RottenTomatoes == max(df_movie_filter.RottenTomatoes)]
print(output)
# Out:
#                Movie  Story  RottenTomatoes
# 343  The Hurt Locker  Quest            97.0
# 629      The Muppets  Quest            97.0

# %%
selected_data=dataset.loc[:,['WorldGross','Genre']]
df=pd.DataFrame(selected_data)
df_notnull_genre=df[df.Genre.notnull()]
df_notnull_worldgross=df_notnull_genre[df_notnull_genre.WorldGross.notnull()]
df_final= df_notnull_worldgross
Series_genre = df_final['WorldGross'].groupby(df_final['Genre']).sum()
df_new=pd.DataFrame(Series_genre)
genre=df_new.sort_values(by='WorldGross', ascending=False).head(10)  #finding top 10 genre movies released
print(genre)
# Out:
#            WorldGross
# Genre
# Action      40508.804
# Comedy      17840.217
# Animation   17383.285
# Drama        8690.208
# Adventure    7168.277
# Thriller     6555.977
# Horror       4239.239
# Romance      2874.960
# Fantasy      1957.708
# Biography    1663.770

# %%
plt.bar(df["RottenTomatoes"], df["Profitability"],facecolor='red')
plt.xlabel('RottenTomotoes', size = 20)
plt.ylabel('Profit', size = 20)
plt.title("Graph", size = 10)
plt.show()

# %%
df = pd.DataFrame({'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'],
                   'last_name': ['Miller', 'Jacobson', ".", 'Milner', 'Cooze'],
                   'age': [42, 52, 36, 24, 73],
                   'preTestScore': [4, 24, 31, ".", "."],
                   'postTestScore': ["25,000", "94,000", 57, 62, 70]})
df.to_csv("test.csv")

# %%
pd1=pd.read_csv("test.csv")
pd1.head()
# Out:
#    Unnamed: 0 first_name last_name  age preTestScore postTestScore
# 0           0      Jason    Miller   42            4        25,000
# 1           1      Molly  Jacobson   52           24        94,000
# 2           2       Tina         .   36           31            57
# 3           3       Jake    Milner   24            .            62
# 4           4        Amy     Cooze   73            .            70

# %%
pd4=pd.read_csv("test.csv",header=None)
pd4
# Out:
#      0           1          2    3             4              5
# 0  NaN  first_name  last_name  age  preTestScore  postTestScore
# 1  0.0       Jason     Miller   42             4         25,000
# 2  1.0       Molly   Jacobson   52            24         94,000
# 3  2.0        Tina          .   36            31             57
# 4  3.0        Jake     Milner   24             .             62
# 5  4.0         Amy      Cooze   73             .             70

# %%
df_with_index = pd.read_csv("test.csv", index_col=[
                            "first_name", "last_name"])
print(df_with_index)
# Out:
#                       Unnamed: 0  age preTestScore postTestScore
# first_name last_name
# Jason      Miller              0   42            4        25,000
# Molly      Jacobson            1   52           24        94,000
# Tina       .                   2   36           31            57
# Jake       Milner              3   24            .            62
# Amy        Cooze               4   73            .            70

# %%
boolean_df = df.isnull().any()
print(boolean_df)
# Out:
# first_name       False
# last_name        False
# age              False
# preTestScore     False
# postTestScore    False
# dtype: bool

# %%
df_skip_rows = pd.read_csv("test.csv", skiprows=3)
print(df_skip_rows)
# Out:
#    2  Tina       .  36 31  57
# 0  3  Jake  Milner  24  .  62
# 1  4   Amy   Cooze  73  .  70
